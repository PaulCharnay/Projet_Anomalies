# %% [markdown]
# **Découverte jeu de données**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("real_13.csv")

# %%
anom = data[data["is_anomaly"] == 1]
plt.plot(data["timestamp"], data["value"])
plt.scatter(anom["timestamp"], anom["value"], color="red", marker='o')
plt.show()

# %%
data[data["is_anomaly"] == 1]
# Out:
#       timestamp  value  is_anomaly
# 142         143  19709           1
# 143         144  20679           1
# 144         145  16587           1
# 973         974  17681           1
# 974         975  22448           1
# 975         976  23928           1
# 1431       1432  19180           1
# 1432       1433  26795           1
# 1433       1434  24238           1
# 1434       1435  23181           1
# 1435       1436  20446           1
# 1436       1437  16193           1
